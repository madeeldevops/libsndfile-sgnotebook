# %%
# !pip install fastaudio torch==1.8.1 torchvision==0.9.1 torchaudio==0.8.1 wwf timm
# Out:
# Collecting fastaudio
#   Downloading fastaudio-1.0.2-py2.py3-none-any.whl (23 kB)
# Collecting torch==1.8.1
#   Downloading torch-1.8.1-cp36-cp36m-manylinux1_x86_64.whl (804.1 MB)
#      |████████████████████████████████| 804.1 MB 2.3 kB/s eta 0:00:011   |                                | 2.0 MB 19.6 MB/s eta 0:00:41     |████▏                           | 105.9 MB 72.3 MB/s eta 0:00:10     |████▉                           | 121.8 MB 72.3 MB/s eta 0:00:10     |█████████                       | 227.0 MB 72.1 MB/s eta 0:00:08     |███████████████                 | 377.0 MB 67.1 MB/s eta 0:00:07
# Collecting torchvision==0.9.1
#   Downloading torchvision-0.9.1-cp36-cp36m-manylinux1_x86_64.whl (17.4 MB)
#      |████████████████████████████████| 17.4 MB 33.3 MB/s eta 0:00:01
# Collecting torchaudio==0.8.1
#   Downloading torchaudio-0.8.1-cp36-cp36m-manylinux1_x86_64.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 46.5 MB/s eta 0:00:01
# Collecting wwf
#   Downloading wwf-0.0.16-py3-none-any.whl (20 kB)
# Collecting timm
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 52.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from torch==1.8.1) (1.19.5)
# Requirement already satisfied: typing-extensions in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from torch==1.8.1) (3.10.0.2)
# Requirement already satisfied: dataclasses in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from torch==1.8.1) (0.8)
# Requirement already satisfied: pillow>=4.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from torchvision==0.9.1) (8.3.2)
# Collecting librosa==0.8
#   Downloading librosa-0.8.0.tar.gz (183 kB)
#      |████████████████████████████████| 183 kB 73.3 MB/s eta 0:00:01
# Collecting fastai==2.3.1
#   Downloading fastai-2.3.1-py3-none-any.whl (194 kB)
#      |████████████████████████████████| 194 kB 68.7 MB/s eta 0:00:01
# Collecting fastcore==1.3.20
#   Downloading fastcore-1.3.20-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 3.4 MB/s  eta 0:00:01
# Collecting colorednoise>=1.1
#   Downloading colorednoise-1.1.1.tar.gz (5.2 kB)
# Requirement already satisfied: IPython in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fastaudio) (7.16.1)
# Requirement already satisfied: scipy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fastai==2.3.1->fastaudio) (1.5.3)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fastai==2.3.1->fastaudio) (1.1.5)
# Requirement already satisfied: pyyaml in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fastai==2.3.1->fastaudio) (5.4.1)
# Requirement already satisfied: matplotlib in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fastai==2.3.1->fastaudio) (3.3.4)
# Requirement already satisfied: scikit-learn in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fastai==2.3.1->fastaudio) (0.24.1)
# Requirement already satisfied: packaging in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fastai==2.3.1->fastaudio) (21.0)
# Requirement already satisfied: requests in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fastai==2.3.1->fastaudio) (2.26.0)
# Collecting spacy<4
#   Downloading spacy-3.2.0-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.0 MB)
#      |████████████████████████████████| 6.0 MB 71.0 MB/s eta 0:00:01
# Collecting fastprogress>=0.2.4
#   Downloading fastprogress-1.0.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: pip in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from fastai==2.3.1->fastaudio) (21.2.4)
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 52.9 MB/s eta 0:00:01
# Requirement already satisfied: joblib>=0.14 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from librosa==0.8->fastaudio) (1.0.1)
# Requirement already satisfied: decorator>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from librosa==0.8->fastaudio) (4.4.2)
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#      |████████████████████████████████| 323 kB 51.6 MB/s eta 0:00:01
# Requirement already satisfied: numba>=0.43.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from librosa==0.8->fastaudio) (0.52.0)
# Requirement already satisfied: soundfile>=0.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from librosa==0.8->fastaudio) (0.10.3.post1)
# Collecting pooch>=1.0
#   Downloading pooch-1.5.2-py3-none-any.whl (57 kB)
#      |████████████████████████████████| 57 kB 7.8 MB/s  eta 0:00:01
# Requirement already satisfied: setuptools in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from numba>=0.43.0->librosa==0.8->fastaudio) (58.3.0)
# Requirement already satisfied: llvmlite<0.36,>=0.35.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from numba>=0.43.0->librosa==0.8->fastaudio) (0.35.0)
# Requirement already satisfied: appdirs in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pooch>=1.0->librosa==0.8->fastaudio) (1.4.4)
# Requirement already satisfied: six>=1.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from resampy>=0.2.2->librosa==0.8->fastaudio) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit-learn->fastai==2.3.1->fastaudio) (2.1.0)
# Requirement already satisfied: cffi>=1.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from soundfile>=0.9.0->librosa==0.8->fastaudio) (1.15.0)
# Requirement already satisfied: pycparser in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from cffi>=1.0->soundfile>=0.9.0->librosa==0.8->fastaudio) (2.20)
# Collecting wasabi<1.1.0,>=0.8.1
#   Downloading wasabi-0.8.2-py3-none-any.whl (23 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.8
#   Downloading spacy_legacy-3.0.8-py2.py3-none-any.whl (14 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4
#   Downloading pydantic-1.8.2-cp36-cp36m-manylinux2014_x86_64.whl (10.2 MB)
#      |████████████████████████████████| 10.2 MB 58.0 MB/s eta 0:00:01
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.3.0-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 70.5 MB/s eta 0:00:01
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.6-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35 kB)
# Collecting thinc<8.1.0,>=8.0.12
#   Downloading thinc-8.0.13-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (629 kB)
#      |████████████████████████████████| 629 kB 40.0 MB/s eta 0:00:01
# Collecting pathy>=0.3.5
#   Downloading pathy-0.6.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 172 kB/s  eta 0:00:01
# Collecting srsly<3.0.0,>=2.4.1
#   Downloading srsly-2.4.2-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (451 kB)
#      |████████████████████████████████| 451 kB 72.9 MB/s eta 0:00:01
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.6-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (127 kB)
#      |████████████████████████████████| 127 kB 75.1 MB/s eta 0:00:01
# Collecting blis<0.8.0,>=0.4.0
#   Downloading blis-0.7.5-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.9 MB)
#      |████████████████████████████████| 9.9 MB 41.0 MB/s eta 0:00:01
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.1-py3-none-any.whl (7.0 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<4->fastai==2.3.1->fastaudio) (4.62.3)
# Collecting typer<0.5.0,>=0.3.0
#   Downloading typer-0.4.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: jinja2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from spacy<4->fastai==2.3.1->fastaudio) (2.11.3)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.6-py3-none-any.whl (17 kB)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.6-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from catalogue<2.1.0,>=2.0.6->spacy<4->fastai==2.3.1->fastaudio) (3.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging->fastai==2.3.1->fastaudio) (3.0.1)
# Collecting smart-open<6.0.0,>=5.0.0
#   Downloading smart_open-5.2.1-py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 7.9 MB/s  eta 0:00:01
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->fastai==2.3.1->fastaudio) (2.0.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->fastai==2.3.1->fastaudio) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->fastai==2.3.1->fastaudio) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests->fastai==2.3.1->fastaudio) (3.3)
# Requirement already satisfied: contextvars<3,>=2.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from thinc<8.1.0,>=8.0.12->spacy<4->fastai==2.3.1->fastaudio) (2.4)
# Requirement already satisfied: immutables>=0.9 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from contextvars<3,>=2.4->thinc<8.1.0,>=8.0.12->spacy<4->fastai==2.3.1->fastaudio) (0.15)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from typer<0.5.0,>=0.3.0->spacy<4->fastai==2.3.1->fastaudio) (7.1.2)
# Requirement already satisfied: pygments in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from IPython->fastaudio) (2.8.0)
# Requirement already satisfied: pickleshare in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from IPython->fastaudio) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from IPython->fastaudio) (4.3.3)
# Requirement already satisfied: pexpect in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from IPython->fastaudio) (4.8.0)
# Requirement already satisfied: backcall in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from IPython->fastaudio) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from IPython->fastaudio) (3.0.5)
# Requirement already satisfied: jedi>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from IPython->fastaudio) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jedi>=0.10->IPython->fastaudio) (0.7.0)
# Requirement already satisfied: wcwidth in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->fastaudio) (0.2.5)
# Requirement already satisfied: ipython-genutils in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from traitlets>=4.2->IPython->fastaudio) (0.2.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from jinja2->spacy<4->fastai==2.3.1->fastaudio) (1.1.1)
# Requirement already satisfied: python-dateutil>=2.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from matplotlib->fastai==2.3.1->fastaudio) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from matplotlib->fastai==2.3.1->fastaudio) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from matplotlib->fastai==2.3.1->fastaudio) (0.10.0)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->fastai==2.3.1->fastaudio) (2021.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pexpect->IPython->fastaudio) (0.7.0)
# Building wheels for collected packages: librosa, audioread, colorednoise, resampy
#   Building wheel for librosa (setup.py) ... done
#   Created wheel for librosa: filename=librosa-0.8.0-py3-none-any.whl size=201395 sha256=8a3a2e0b8e54633a14e07151ad184b325f2af250d886ed78224ae13d87cd8a92
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/32/2c/ce/86e49d4769aceba728421c24c0d726054bf4ca01175ff42bdd
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23153 sha256=a7dd7023dd2f8afec7ab60ae11613c9d6cc31e521c64240f035fd944f6085dfa
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/de/14/0a/863e4ed680b3204444cf486733e609d7ff7abe8fceafab67dc
#   Building wheel for colorednoise (setup.py) ... done
#   Created wheel for colorednoise: filename=colorednoise-1.1.1-py3-none-any.whl size=3981 sha256=3d8cd19a44d8308c526c785de0a7411ba22ccf38be0fbbbf0cfa7bf2b25c746b
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/54/0c/1a/bbb31ea073c1557707b8e1c35037bb5124fae5be551cf03fdc
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320732 sha256=808778a7ad613c97ec59fa0cddf935294cf6d738b76d06c2ff1721d1ad580eaf
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/cf/d4/04/49d8824a42bd9f9b11d502727965b9997f0d41d2b22ae4f645
# Successfully built librosa audioread colorednoise resampy
# Installing collected packages: murmurhash, cymem, catalogue, wasabi, typer, srsly, smart-open, pydantic, preshed, blis, torch, thinc, spacy-loggers, spacy-legacy, pathy, langcodes, torchvision, spacy, resampy, pooch, fastprogress, fastcore, audioread, torchaudio, timm, librosa, fastai, colorednoise, wwf, fastaudio
# Successfully installed audioread-2.1.9 blis-0.7.5 catalogue-2.0.6 colorednoise-1.1.1 cymem-2.0.6 fastai-2.3.1 fastaudio-1.0.2 fastcore-1.3.20 fastprogress-1.0.0 langcodes-3.3.0 librosa-0.8.0 murmurhash-1.0.6 pathy-0.6.1 pooch-1.5.2 preshed-3.0.6 pydantic-1.8.2 resampy-0.2.2 smart-open-5.2.1 spacy-3.2.0 spacy-legacy-3.0.8 spacy-loggers-1.0.1 srsly-2.4.2 thinc-8.0.13 timm-0.4.12 torch-1.8.1 torchaudio-0.8.1 torchvision-0.9.1 typer-0.4.0 wasabi-0.8.2 wwf-0.0.16
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
from fastai.vision.all import *
from fastaudio.core.all import *
from fastaudio.augment.all import *
from fastaudio.ci import skip_if_ci
import argparse
import warnings
warnings.filterwarnings('ignore')
#torchaudio.set_audio_backend('sox_io')
import time

import torchaudio
import torch
import torchvision
print('torchaudio-version::',torchaudio.__version__)
print('torchvision-version:',torchvision.__version__)
print('torch-version:',torch.__version__)
# Out:
# torchaudio-version:: 0.8.1
# torchvision-version: 0.9.1+cu102
# torch-version: 1.8.1+cu102

# %%
model = load_learner("Model-CK-0.918")

# %%
model.predict(Path("file_example_MP3_1MG.mp3"))
